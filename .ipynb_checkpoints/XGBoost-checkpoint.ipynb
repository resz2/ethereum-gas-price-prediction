# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('processed.csv')
df
# Out:
#          Unnamed: 0  difficulty      size  gas_limit  transaction_count  \
# 0                 0    0.497304  1.525696   1.376636           0.768851
# 1                 1   -0.175685 -0.151892   0.634122          -0.146996
# 2                 2    0.074976 -1.414733  -0.108392          -0.544231
# 3                 3    0.730501  0.085234   0.634122          -0.334579
# 4                 4    1.549208  0.792288   0.634122           0.934365
# ...             ...         ...       ...        ...                ...
# 1104905     1122538    1.973237 -0.512900   1.003022           2.423996
# 1104906     1122539    1.478965  0.163406   0.631942           2.412962
# 1104907     1122540    1.827774  1.181778  -0.094451           2.600545
# 1104908     1122541    1.963733  1.120832   0.633412           2.865369
# 1104909     1122542    1.827774  1.181778  -0.094451           2.600545
#
#               gas  past_min  past_mean  past_max     block_min
# 0       -0.306444 -0.471469  -0.552406 -0.503274  1.200000e+10
# 1        0.373021  0.021040   0.091190  0.868203  6.000000e+09
# 2       -0.382288 -0.202041  -0.555886 -0.473770  4.000000e+09
# 3       -0.348186  0.036881  -0.276384 -0.418639  4.500000e+09
# 4       -0.309031 -0.300726  -0.273407 -0.412249  1.000000e+10
# ...           ...       ...        ...       ...           ...
# 1104905 -0.308021 -0.155295  -0.473794 -0.430499  9.400000e+01
# 1104906 -0.308021  0.442009   0.074412 -0.409621  9.400000e+01
# 1104907 -0.308021 -0.492245  -0.301149 -0.473260  9.400000e+01
# 1104908 -0.308021 -0.041028  -0.263162 -0.458805  9.400000e+01
# 1104909 -0.308021 -0.492245  -0.301149 -0.473260  9.400000e+01
#
# [1104910 rows x 10 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# ### Train-Test split

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['block_min'], axis=1)
y = df['block_min']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
xgb_r = XGBRegressor(objective ='reg:squarederror', n_estimators=25, max_depth=20)
xgb_r.fit(x_train[:10000], y_train[:10000])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=20, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=25, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

xgb = XGBRegressor(objective ='reg:squarederror')
no_of_estimators = [10, 30, 60, 100]
maximumdepth = [5, 10, 15, 20, 25, 30]
parameters = {'n_estimators': no_of_estimators ,'max_depth': maximumdepth}
model = GridSearchCV(estimator=xgb, param_grid=parameters, cv=3, scoring='r2', return_train_score=True, verbose=1)
model.fit(x_train[:100000], y_train[:100000])

print('yay')
print("Model with best parameters :\n", model.best_params_)
train_auc = model.cv_results_['mean_train_score'].reshape(len(maximumdepth), len(no_of_estimators))
cv_auc = model.cv_results_['mean_test_score'].reshape(len(maximumdepth), len(no_of_estimators))

f, axes = plt.subplots(1, 2,figsize=(15,5))

for i in range(2):
    title = train_auc if i == 0 else cv_auc
    sns.heatmap(title, xticklabels=no_of_estimators, yticklabels=maximumdepth, annot=True, ax=axes[i])
    axes[i].set_title(f"Gridearch {'Train' if i==0 else 'CV'}")
    axes[i].set_xlabel("no_of_estimators")
    axes[i].set_ylabel("maximum_depth")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\sklearn.py", line 789, in fit
#     self._Booster = train(
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\training.py", line 112, in _train_internal
#     return bst.copy()
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1533, in copy
#     return self.__copy__()
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1519, in __copy__
#     return self.__deepcopy__(None)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1523, in __deepcopy__
#     return Booster(model_file=self)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1317, in __init__
#     state = model_file.__getstate__()
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1433, in __getstate__
#     _check_call(_LIB.XGBoosterSerializeToBuffer(self.handle,
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: bad allocation
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\sklearn.py", line 789, in fit
#     self._Booster = train(
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\training.py", line 112, in _train_internal
#     return bst.copy()
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1533, in copy
#     return self.__copy__()
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1519, in __copy__
#     return self.__deepcopy__(None)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1523, in __deepcopy__
#     return Booster(model_file=self)
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 1322, in __init__
#     _check_call(
#   File "c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: bad allocation
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.71357886 0.77417634 0.82956793 0.87701618 0.87073575 0.94312213
#  0.98074397 0.99336572 0.9747851  0.99553993 0.99870224 0.99903223
#  0.99425442 0.9991945  0.99923549 0.99923629 0.99598161 0.99911964
#  0.99912054 0.99912054 0.99609351 0.99911242        nan        nan]
#   warnings.warn(
# c:\users\aryan\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the train scores are non-finite: [0.7165605  0.77963675 0.8362845  0.88386665 0.87748944 0.9490883
#  0.98453764 0.99580985 0.9775159  0.99721848 0.99977389 0.99998519
#  0.99549105 0.9999762  0.99999984 1.         0.99708987 0.99999989
#  1.         1.         0.99718518 0.99999993        nan        nan]
#   warnings.warn(
# yay
# Model with best parameters :
#  {'max_depth': 20, 'n_estimators': 100}
